# %% [markdown]
# ## Problem
# You want to implement word embeddings.

# %% [markdown]
# ## word2vec
# word2vec is the deep learning Google framework to train
# word embeddings. It will use all the words of the whole corpus and predict
# the nearby words. It will create a vector for all the words present in the
# corpus in a way so that the context is captured. It also outperforms any
# other methodologies in the space of word similarity and word analogies.
# There are mainly 2 types in word2vec.
#
# • Skip-Gram
#
# • Continuous Bag of Words (CBOW)

# %% [markdown]
# ## Skip-Gram

# %%
sentences = [['I', 'love', 'nlp'],
            ['I', 'will', 'learn', 'nlp', 'in', '2','months'],
            ['nlp', 'is', 'future'],
            ['nlp', 'saves', 'time', 'and', 'solves',
            'lot', 'of', 'industry', 'problems'],
            ['nlp', 'uses', 'machine', 'learning']]

# %%
#import library
# !pip install gensim
import gensim
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
# training the model
skipgram = Word2Vec(sentences, size =50, window = 3, min_count=1,sg = 1)
print(skipgram)

# access vector for one word
print(skipgram['nlp'])
# Out:
# Word2Vec(vocab=21, size=50, alpha=0.025)
# [ 0.00754995 -0.0066583  -0.00495442 -0.00545891  0.00309945 -0.00193227
#  -0.00487117 -0.00681389 -0.00553809  0.00369458 -0.00834626  0.00887067
#  -0.00370442 -0.00647862 -0.00551206  0.00954107  0.00709682 -0.00972768
#   0.00689722 -0.00600665 -0.00870242  0.00013856 -0.00671963 -0.00544145
#  -0.00190613 -0.00429549  0.00800856 -0.00889922  0.00837875  0.00658606
#   0.00377342 -0.00332118 -0.00823085  0.00872385 -0.00101821 -0.00633802
#  -0.00118359  0.00704717  0.00806975  0.00491774  0.00055045  0.00104688
#   0.00151279  0.00465629 -0.00892701 -0.0027105   0.00713803 -0.00114777
#  -0.00139374 -0.00094385]
# D:\workspace\python\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
# save model
skipgram.save('skipgram.bin')
# load model
skipgram = Word2Vec.load('skipgram.bin')

# %%
# T – SNE plot
X = skipgram[skipgram.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# create a scatter plot of the projection
# %matplotlib inline
pyplot.scatter(result[:, 0], result[:, 1])
words = list(skipgram.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# D:\workspace\python\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# ## Continuous Bag of Words (CBOW)

# %%
#import library
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
#Example sentences
sentences = [['I', 'love', 'nlp'],
            ['I', 'will', 'learn', 'nlp', 'in', '2','months'],
            ['nlp', 'is', 'future'],
            ['nlp', 'saves', 'time', 'and', 'solves',
            'lot', 'of', 'industry', 'problems'],
            ['nlp', 'uses', 'machine', 'learning']]

# training the model
cbow = Word2Vec(sentences, size =50, window = 3, min_count=1,sg = 1)
print(cbow)
# access vector for one word
print(cbow['nlp'])
# save model
cbow.save('cbow.bin')
# load model
cbow = Word2Vec.load('cbow.bin')
# T – SNE plot
X = cbow[cbow.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(cbow.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# D:\workspace\python\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "
# D:\workspace\python\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# D:\workspace\python\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Word2Vec(vocab=21, size=50, alpha=0.025)
# [ 0.00754995 -0.0066583  -0.00495442 -0.00545891  0.00309945 -0.00193227
#  -0.00487117 -0.00681389 -0.00553809  0.00369458 -0.00834626  0.00887067
#  -0.00370442 -0.00647862 -0.00551206  0.00954107  0.00709682 -0.00972768
#   0.00689722 -0.00600665 -0.00870242  0.00013856 -0.00671963 -0.00544145
#  -0.00190613 -0.00429549  0.00800856 -0.00889922  0.00837875  0.00658606
#   0.00377342 -0.00332118 -0.00823085  0.00872385 -0.00101821 -0.00633802
#  -0.00118359  0.00704717  0.00806975  0.00491774  0.00055045  0.00104688
#   0.00151279  0.00465629 -0.00892701 -0.0027105   0.00713803 -0.00114777
#  -0.00139374 -0.00094385]

# %% [markdown]
# Download the model from the below path and keep it in your local
# storage:
#
# https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit
#
# Import the gensim package and follow the steps to understand
# Google’s word2vec.

# %%
# import gensim package
import gensim
# load the saved model
model = gensim.models.Word2Vec.load_word2vec_format('C:\\Users\\GoogleNews-vectors-negative300.bin', binary=True)
#Checking how similarity works.
print (model.similarity('this', 'is'))

# %%
#Lets check one more.
print (model.similarity('post', 'book'))
